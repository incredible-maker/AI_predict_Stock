# %%
# !pip install yfinance
# Out:
# Collecting yfinance
#   Downloading yfinance-0.2.22-py2.py3-none-any.whl (63 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.2/63.2 kB 9.4 MB/s eta 0:00:00
# Requirement already satisfied: pandas>=1.3.0 in /home/jacky/miniconda2/envs/jacky/lib/python3.9/site-packages (from yfinance) (2.0.1)
# Requirement already satisfied: numpy>=1.16.5 in /home/jacky/miniconda2/envs/jacky/lib/python3.9/site-packages (from yfinance) (1.23.5)
# Requirement already satisfied: requests>=2.26 in /home/jacky/miniconda2/envs/jacky/lib/python3.9/site-packages (from yfinance) (2.28.2)
# Collecting multitasking>=0.0.7 (from yfinance)
#   Downloading multitasking-0.0.11-py3-none-any.whl (8.5 kB)
# Collecting lxml>=4.9.1 (from yfinance)
#   Downloading lxml-4.9.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (7.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.1/7.1 MB 88.6 MB/s eta 0:00:00:00:0100:01
# Collecting appdirs>=1.4.4 (from yfinance)
#   Using cached appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Requirement already satisfied: pytz>=2022.5 in /home/jacky/miniconda2/envs/jacky/lib/python3.9/site-packages (from yfinance) (2023.3)
# Collecting frozendict>=2.3.4 (from yfinance)
#   Downloading frozendict-2.3.8-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (114 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.8/114.8 kB 24.9 MB/s eta 0:00:00
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /home/jacky/miniconda2/envs/jacky/lib/python3.9/site-packages (from yfinance) (4.12.2)
# Collecting html5lib>=1.1 (from yfinance)
#   Using cached html5lib-1.1-py2.py3-none-any.whl (112 kB)
# Requirement already satisfied: soupsieve>1.2 in /home/jacky/miniconda2/envs/jacky/lib/python3.9/site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.3.2.post1)
# Requirement already satisfied: six>=1.9 in /home/jacky/miniconda2/envs/jacky/lib/python3.9/site-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: webencodings in /home/jacky/miniconda2/envs/jacky/lib/python3.9/site-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/jacky/miniconda2/envs/jacky/lib/python3.9/site-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: tzdata>=2022.1 in /home/jacky/miniconda2/envs/jacky/lib/python3.9/site-packages (from pandas>=1.3.0->yfinance) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/jacky/miniconda2/envs/jacky/lib/python3.9/site-packages (from requests>=2.26->yfinance) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/jacky/miniconda2/envs/jacky/lib/python3.9/site-packages (from requests>=2.26->yfinance) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/jacky/miniconda2/envs/jacky/lib/python3.9/site-packages (from requests>=2.26->yfinance) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /home/jacky/miniconda2/envs/jacky/lib/python3.9/site-packages (from requests>=2.26->yfinance) (2022.12.7)
# Installing collected packages: multitasking, appdirs, lxml, html5lib, frozendict, yfinance
# Successfully installed appdirs-1.4.4 frozendict-2.3.8 html5lib-1.1 lxml-4.9.2 multitasking-0.0.11 yfinance-0.2.22

# %%
import yfinance as yf

# Define the ticker symbol for the stock you want to fetch data for
ticker_symbol = "TEMN.SW"

# Fetch historical stock price data
data = yf.download(ticker_symbol, start="2020-01-01", end="2023-06-28")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
data
# Out:
#                   Open        High         Low       Close   Adj Close  Volume
# Date
# 2020-01-03  153.100006  154.000000  151.550003  153.600006  147.812164  274068
# 2020-01-06  152.350006  153.300003  151.100006  153.300003  147.523468  225145
# 2020-01-07  153.850006  156.500000  151.500000  151.500000  145.791321  268437
# 2020-01-08  151.100006  153.000000  149.500000  152.850006  147.090439  245846
# 2020-01-09  154.000000  155.949997  152.800003  155.149994  149.303757  280922
# ...                ...         ...         ...         ...         ...     ...
# 2023-06-21   71.139999   71.540001   69.820000   70.260002   70.260002  215430
# 2023-06-22   69.860001   70.260002   69.459999   70.180000   70.180000  124855
# 2023-06-23   69.820000   70.099998   68.680000   69.160004   69.160004  168352
# 2023-06-26   69.000000   69.639999   67.980003   68.720001   68.720001  207825
# 2023-06-27   69.080002   69.120003   68.260002   68.559998   68.559998  112393
#
# [881 rows x 6 columns]

# %%
import yfinance as yf

msft = yf.Ticker("TEMN.SW")

# get all stock info
msft.info

# get historical market data
hist = msft.history(period="1mo")

# show meta information about the history (requires history() to be called first)
msft.history_metadata

# show actions (dividends, splits, capital gains)
msft.actions
msft.dividends
msft.splits
msft.capital_gains  # only for mutual funds & etfs

# show share count
msft.get_shares_full(start="2023-01-01", end=None)

# show financials:
# - income statement
msft.income_stmt
msft.quarterly_income_stmt
# - balance sheet
msft.balance_sheet
msft.quarterly_balance_sheet
# - cash flow statement
msft.cashflow
msft.quarterly_cashflow
# see `Ticker.get_income_stmt()` for more options

# show holders
msft.major_holders
msft.institutional_holders
msft.mutualfund_holders

# Show future and historic earnings dates, returns at most next 4 quarters and last 8 quarters by default. 
# Note: If more are needed use msft.get_earnings_dates(limit=XX) with increased limit argument.
msft.earnings_dates

# show ISIN code - *experimental*
# ISIN = International Securities Identification Number
msft.isin

# show options expirations
msft.options

# show news
msft.news
# Out:
# [{'uuid': 'b06112fb-e73b-372a-b2fa-b96b13aa7ea1',
#   'title': 'Q3 2023 Micron Technology Inc Post Earnings Analyst Call Earnings Call',
#   'publisher': 'Thomson Reuters StreetEvents',
#   'link': 'https://finance.yahoo.com/news/q3-2023-micron-technology-inc-115513694.html',
#   'providerPublishTime': 1688039713,
#   'type': 'STORY',
#   'relatedTickers': ['MU']},
#  {'uuid': '1afbfefb-dce2-3e81-bf1a-827f8c90e45d',
#   'title': 'Morning News Call - Canada, June 29',
#   'publisher': 'Reuters',
#   'link': 'https://finance.yahoo.com/news/morning-news-call-canada-june-115405334.html',
#   'providerPublishTime': 1688039645,
#   'type': 'STORY'},
#  {'uuid': '0ffbc301-7f48-30b8-ba3b-4ab751992984',
#   'title': 'SPCE Stock Rockets Ahead Of Virgin Galactic Launch; How To Watch The Commercial Space Flight',
#   'publisher': "Investor's Business Daily",
#   'link': 'https://finance.yahoo.com/m/0ffbc301-7f48-30b8-ba3b-4ab751992984/spce-stock-rockets-ahead-of.html',
#   'providerPublishTime': 1688039508,
#   'type': 'STORY',
#   'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/P86cz9139cY1g9o3RaSrvg--~B/aD01NzI7dz0xMDEyO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/ibd.com/90ae9007652fb09e8101dc6e45dd05ba',
#      'width': 1012,
#      'height': 572,
#      'tag': 'original'},
#     {'url': 'https://s.yimg.com/uu/api/res/1.2/8Ww4.8iRv2vusrjW9Wwgbw--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/ibd.com/90ae9007652fb09e8101dc6e45dd05ba',
#      'width': 140,
#      'height': 140,
#      'tag': '140x140'}]},
#   'relatedTickers': ['SPCE']},
#  {'uuid': '9b6def12-4ba7-314c-a46b-169d5161a961',
#   'title': 'EU-funded hybrid car prototype explodes in Italy, killing two people',
#   'publisher': 'Reuters',
#   'link': 'https://finance.yahoo.com/news/eu-funded-hybrid-car-prototype-115101705.html',
#   'providerPublishTime': 1688039461,
#   'type': 'STORY'},
#  {'uuid': '56723767-0234-3bc4-af3a-106f23b2e505',
#   'title': 'Virgin Galactic to Launch First Commercial Spaceflight After Setbacks, Delays',
#   'publisher': 'The Wall Street Journal',
#   'link': 'https://finance.yahoo.com/m/56723767-0234-3bc4-af3a-106f23b2e505/virgin-galactic-to-launch.html',
#   'providerPublishTime': 1688039400,
#   'type': 'STORY',
#   'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/EC9xSQXt5xlE1Y9d4sAraQ--~B/aD02NDA7dz0xMjgwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/wsj.com/44a097aa6288ec93b4211ad352ea38f2',
#      'width': 1280,
#      'height': 640,
#      'tag': 'original'},
#     {'url': 'https://s.yimg.com/uu/api/res/1.2/UviI2HOplxIteI2T06YRrA--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/wsj.com/44a097aa6288ec93b4211ad352ea38f2',
#      'width': 140,
#      'height': 140,
#      'tag': '140x140'}]}},
#  {'uuid': '64e016cc-6c1c-33b8-95b4-af656e162c57',
#   'title': 'Will a "Super App" Strategy Send Coinbase Stock Soaring?',
#   'publisher': 'Motley Fool',
#   'link': 'https://finance.yahoo.com/m/64e016cc-6c1c-33b8-95b4-af656e162c57/will-a-%22super-app%22-strategy.html',
#   'providerPublishTime': 1688039400,
#   'type': 'STORY',
#   'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/cf3g06jwj7FM0J3xcyjlbA--~B/aD0xNDE0O3c9MjEyMDthcHBpZD15dGFjaHlvbg--/https://media.zenfs.com/en/motleyfool.com/5a7bfe9a202a6597ff311c9c17b6ed24',
#      'width': 2120,
#      'height': 1414,
#      'tag': 'original'},
#     {'url': 'https://s.yimg.com/uu/api/res/1.2/NcwbCpDfczrXpnVFkoWHXw--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/motleyfool.com/5a7bfe9a202a6597ff311c9c17b6ed24',
#      'width': 140,
#      'height': 140,
#      'tag': '140x140'}]},
#   'relatedTickers': ['COIN']},
#  {'uuid': '7be0fb80-8d6c-3eb7-82ed-7815f3d809de',
#   'title': 'VIN Foundation Announces 7th Annual Solutions for the Profession Competition Winners',
#   'publisher': 'PR Newswire',
#   'link': 'https://finance.yahoo.com/news/vin-foundation-announces-7th-annual-115000666.html',
#   'providerPublishTime': 1688039400,
#   'type': 'STORY',
#   'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/ny3yhf3ythEPWKveLoIh2g--~B/aD0xNjt3PTE2O2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/prnewswire.com/5d567a6aa0d1664619f809929ca55a10',
#      'width': 16,
#      'height': 16,
#      'tag': 'original'},
#     {'url': 'https://s.yimg.com/uu/api/res/1.2/IIwtQDwl.mFrte9_xPDx.A--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/prnewswire.com/5d567a6aa0d1664619f809929ca55a10',
#      'width': 140,
#      'height': 140,
#      'tag': '140x140'}]}},
#  {'uuid': '84e5c628-5765-32bb-b0ad-97b31ac63acd',
#   'title': 'Genius Metals Acquires a 100% interest in the Paka property located in James Bay, Québec',
#   'publisher': 'CNW Group',
#   'link': 'https://finance.yahoo.com/news/genius-metals-acquires-100-interest-115000260.html',
#   'providerPublishTime': 1688039400,
#   'type': 'STORY',
#   'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/Rs.NZ0yYsYSbnq5CH.OKIw--~B/aD0xNTY7dz0zMTI7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en/cnwgroup.com/70c4d94042c5f279dabcb9e2530c0eb5',
#      'width': 312,
#      'height': 156,
#      'tag': 'original'},
#     {'url': 'https://s.yimg.com/uu/api/res/1.2/kCi30heQqxG1REypQCegiw--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/cnwgroup.com/70c4d94042c5f279dabcb9e2530c0eb5',
#      'width': 140,
#      'height': 140,
#      'tag': '140x140'}]},
#   'relatedTickers': ['GNSMF']}]

# %%
# income statement
msft.financials
# Out:
#                                                           2022-12-31
# Tax Effect Of Unusual Items                          -1477278.132129  \
# Tax Rate For Calcs                                          0.216103
# Normalized EBITDA                                        316380000.0
# Total Unusual Items                                       -6836000.0
# Total Unusual Items Excluding Goodwill                    -6836000.0
# Net Income From Continuing Operation Net Minori...       114420000.0
# Reconciled Depreciation                                  141790000.0
# Reconciled Cost Of Revenue                               318425000.0
# Minority Interests                                               0.0
# Net Income Including Noncontrolling Interests            181121000.0
# Net Income Continuous Operations                         181121000.0
# Tax Provision                                             31432000.0
# Pretax Income                                            212553000.0
# Net Non Operating Interest Income Expense                -25213000.0
# Total Other Finance Cost                                   4872000.0
# Interest Expense Non Operating                            22438000.0
# Interest Income Non Operating                              2097000.0
# Operating Income                                         235420000.0
# Operating Expense                                        472070000.0
# Other Operating Expenses                                 194869000.0
# Selling General And Administration                       277201000.0
# Selling And Marketing Expense                            177449000.0
# General And Administrative Expense                        99752000.0
# Gross Profit                                             707490000.0
# Cost Of Revenue                                          264480000.0
# Total Revenue                                            971970000.0
# Operating Revenue                                        971970000.0

# %%
# retrive Gross profit,Cost of revenue,Operating expenses,Operating income,Net income
msft.financials.loc[['Gross Profit','Cost Of Revenue','Total Revenue','Operating Revenue']]
# Out:
#                     2022-12-31   2021-12-31   2020-12-31   2019-12-31
# Gross Profit       631203000.0  641524000.0  588113000.0  707490000.0
# Cost Of Revenue    318425000.0  325478000.0  299245000.0  264480000.0
# Total Revenue      949628000.0  967002000.0  887358000.0  971970000.0
# Operating Revenue  949628000.0  967002000.0  887358000.0  971970000.0

# %%
data
# Out:
#                   Open        High         Low       Close   Adj Close  Volume
# Date
# 2020-01-03  153.100006  154.000000  151.550003  153.600006  147.812164  274068
# 2020-01-06  152.350006  153.300003  151.100006  153.300003  147.523468  225145
# 2020-01-07  153.850006  156.500000  151.500000  151.500000  145.791321  268437
# 2020-01-08  151.100006  153.000000  149.500000  152.850006  147.090439  245846
# 2020-01-09  154.000000  155.949997  152.800003  155.149994  149.303757  280922
# ...                ...         ...         ...         ...         ...     ...
# 2023-06-21   71.139999   71.540001   69.820000   70.260002   70.260002  215430
# 2023-06-22   69.860001   70.260002   69.459999   70.180000   70.180000  124855
# 2023-06-23   69.820000   70.099998   68.680000   69.160004   69.160004  168352
# 2023-06-26   69.000000   69.639999   67.980003   68.720001   68.720001  207825
# 2023-06-27   69.080002   69.120003   68.260002   68.559998   68.559998  112393
#
# [881 rows x 6 columns]

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error


# Select features and target variable
features = data[['Open', 'High', 'Low', 'Volume']]
target = data['Close']

# %%
# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=42)

# %%
# Create a linear regression model
model = LinearRegression()

# Train the model
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# Make predictions on the test data
y_pred = model.predict(X_test)

# Calculate mean squared error
mse = mean_squared_error(y_test, y_pred)

# %%
mse
# Out:
# 1.3481945387198893

# %%
import yfinance as yf

# Define the ticker symbol for the stock you want to fetch data for
ticker_symbol = "ORCL"

# Fetch historical stock price data
data2 = yf.download(ticker_symbol, start="2020-01-01", end="2023-06-28")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
#test the model with ORCL
features2 = data2[['Open', 'High', 'Low', 'Volume']]
target2 = data2['Close']

# Make predictions on the test data
y_pred2 = model.predict(features2)

# Calculate mean squared error
mse2 = mean_squared_error(target2, y_pred2)

# %%
mse2
# Out:
# 3.092017510774372
